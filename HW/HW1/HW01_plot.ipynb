# %% [markdown]
# # Plots of HW 1

# %%
import Pkg
Pkg.add("Plots")
using Plots

gr()
# Out:
#    Resolving package versions...
#   No Changes to `C:\Users\mabah\.julia\environments\v1.11\Project.toml`
#   No Changes to `C:\Users\mabah\.julia\environments\v1.11\Manifest.toml`
# Plots.GRBackend()

# %% [markdown]
# ## Question 2

# %%
f(x) = 0.5x + 1
g(x) = -x + 4

plot(f, 0, 4)
plot!(g)

# %% [markdown]
# ## Question 3

# %%
h(x) = 2x + 1
k(x) = 2x + 4

plot(h, -3, 3)
plot!(k)

# %% [markdown]
# ## Question 4

# %%
y1(x) = 2x^2 + x -4
y2(x) =  2
y3(x) = 0

plot(y1, -3, 3)
plot!(y2)
plot!(y3)

# %%
y1(1.2)
# Out:
# 0.08000000000000007

# %%
y1(-1.7)
# Out:
# 0.07999999999999918

# %%
y1(1.5)
# Out:
# 2.0

# %%
y1(-2)
# Out:
# 2
